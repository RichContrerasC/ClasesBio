# %% [markdown]
# # Clase 2

# %%
from pylab import *
# %matplotlib inline

# %%
def func(x):
    # tabs son importantes para estar dentro de la funcion a realizar.
    y = x**2
    return y

# %%
x = linspace (0,2)
# esta funcion inicia en 0 y termina en 2, dividiendo u obteniendo 50 puntos, si quisiera un valor mayor de 50 lo pondria en un tercer rango (0,2,valor)
plot (x,func(x))

# %%
def func2(x):
    y = x**3
    return y

# %%
a = "Hola mundo"
def  hola():
    a = "Hola de nuevo"
    print a
print a
hola ()
# Out:
# Hola mundo
# Hola de nuevo

# %%
plot (x,func(x),x,func2(x))
xlim (0,1)
ylim (0,1)
# Out:
# (0, 1)

# %%
def func3(a):
    x = linspace (0,a)
    y = x**3
    plot (x,y,'red')

# %%
func3(1)

# %%
puntosy = [1,3,2,5,0.2]
puntosx = [0,1,2,3,4]
puntosz = linspace (0,1,500)
plot (puntosx,puntosy,'o')
show()
plot (x, func(x))

# %%
x = linspace (0,6)
def func4(x,exponente):
    return x**exponente

# %%
for i in range (3):
    y = func4(x,i)
    plot(x,y)

# %%
range (3)
#sirve para numeros enteros
# Out:
# [0, 1, 2]

# %%
arange (0,2,0.5)
#arange sirve para numeros no enteros.
# Out:
# array([ 0. ,  0.5,  1. ,  1.5])

# %%
platillos = [100,130,30]
len (platillos)
# Out:
# 3

# %%
def cuenta (platillos, propina):
    total = 0
    for i in range (len (platillos)):
        total = total + platillos[i]
        
    totalreal = total + total*propina
    print totalreal

# %%
platillos = [50,23,40,121,154]
propina = 0.15
cuenta (platillos, propina)
# Out:
# 446.2
